# %% [markdown]
# # 1.5 Personal Chef — A Complete Agent Application
#
# ## What this notebook demonstrates
#
# This is the **capstone project** for Module 1. It combines every concept from the previous notebooks into one working application:
#
# | Concept | Where it's used |
# |---|---|
# | **Agent** | `create_agent()` — the orchestration backbone |
# | **System prompt** | Chef persona + task description |
# | **Tool** | `web_search` — live recipe lookup via Tavily |
# | **Memory** | `InMemorySaver` — remembers ingredients across turns |
# | **Multi-turn conversation** | `thread_id` + `config` — user can follow up |
#
# ### The application
#
# A **Personal Chef agent** that:
# 1. Takes a list of ingredients the user has at home
# 2. Searches the web for real recipes using those ingredients
# 3. Suggests options and provides full instructions on request
# 4. Remembers the conversation — no need to repeat the ingredient list
#
# This is a pattern you can reuse for any domain: swap "chef" for "travel agent", "fitness coach", "financial advisor", etc.
#
# ---
#
# ### Architecture overview
#
# ```
# User: "I have chicken and rice"
#          │
#          ▼
#     ┌──────────────────────────────────────┐
#     │            Agent Loop                │
#     │  ┌─────────────────────────────┐     │
#     │  │  System Prompt (Chef persona)│     │
#     │  └─────────────────────────────┘     │
#     │                 │                    │
#     │          ┌──────▼──────┐             │
#     │          │   LLM Brain  │             │
#     │          └──────┬──────┘             │
#     │                 │ decides to search  │
#     │          ┌──────▼──────┐             │
#     │          │  web_search  │ → Tavily   │
#     │          │  (tool)      │ ← results  │
#     │          └──────┬──────┘             │
#     │                 │                    │
#     │          ┌──────▼──────┐             │
#     │          │  LLM Brain  │             │
#     │          │ (summarises) │             │
#     │          └──────┬──────┘             │
#     └─────────────────┼────────────────────┘
#                       │
#          ┌────────────▼──────────────┐
#          │  InMemorySaver (thread 1)  │  ← saves history
#          └───────────────────────────┘
#                       │
#          ▼
#     "Here are some recipes: 1) Chicken Fried Rice..."
# ```

# %%
# ============================================================
# CELL 1: Load Environment Variables
# ============================================================
# Requires in .env:
#   OPENAI_API_KEY=sk-...      (for the LLM)
#   TAVILY_API_KEY=tvly-...    (for web search)

from dotenv import load_dotenv
from proto.marshal.compat import message

load_dotenv()
# Out:
# True

# %%
# ============================================================
# CELL 2: Define the Web Search Tool
# ============================================================
# The same Tavily-backed tool from notebook 1.2.
# We define it here so this notebook is self-contained.
#
# The chef agent will use this tool to look up REAL recipes
# from the internet — not hallucinated ones from training data.
# This is critical for a recipe app where accuracy and safety
# (correct cooking times, temperatures) matter.
#
# Query examples the model will construct autonomously:
#   "chicken rice recipe easy"   → for ingredient-based search
#   "chicken fried rice recipe step by step"  → when user asks for details

from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()  # Reads TAVILY_API_KEY from env

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web for information"""
    return tavily_client.search(query)

# %%
# ============================================================
# CELL 3: Define the System Prompt
# ============================================================
# A good system prompt for a tool-enabled agent answers:
#   WHO:   "You are a personal chef"
#   WHAT:  "The user gives you ingredients"
#   HOW:   "Search the web for recipes" (explicitly instructs tool use)
#   OUTPUT:"Return suggestions and instructions on request"
#
# Note that we explicitly say "Using the web search tool" — this
# nudges the model to always search rather than rely on potentially
# stale or hallucinated recipes from training data.
#
# The phrase "if requested" for instructions is important:
# without it the model might dump the full recipe on every turn,
# making the conversation overwhelming. With it, it first suggests
# options and waits to be asked for details.

system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
# ============================================================
# CELL 4: Build the Complete Agent
# ============================================================
# This one create_agent call wires together all the components:
#
#   model="gpt-5-nano"        → the LLM that reasons and generates text
#   tools=[web_search]        → the tool it can call (Tavily search)
#   system_prompt=system_prompt → the chef persona and task instructions
#   checkpointer=InMemorySaver() → per-thread conversation memory
#
# InMemorySaver is initialised fresh here — it starts empty.
# As we make invoke() calls with a thread_id, it fills up with
# the conversation history for that thread.

from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="google_genai:gemini-2.5-flash-lite",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()  # Enables multi-turn memory
)

# %%
# ============================================================
# CELL 5: Turn 1 — Tell the Chef What Ingredients You Have
# ============================================================
# config binds this call to thread_id="1".
# We set config once and reuse it for all turns in this session.
#
# What the agent will do:
#   1. Read the system prompt (chef persona)
#   2. Read the user message (chicken + rice)
#   3. Decide to call web_search (the prompt says to search)
#   4. Formulate a query like "chicken rice leftover recipes"
#   5. Read Tavily results
#   6. Summarise 3-5 recipe options in natural language
#
# The InMemorySaver saves the full message history under thread_id="1"
# after this call — so the next call will remember the ingredients.

from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}  # Identifies this user's session

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some left over chicken and rice. What can I make?")]},
    config   # Attach to thread "1" — memory enabled
)

# Print the chef's recipe suggestions
print(response['messages'][-1].content)
# Out:
# You have chicken and rice! Here are a few ideas for what you can make:
#
# *   **Easy Chicken and Rice:** This is a simple, classic dish that can be customized with different broths or added ingredients like sausage or vegetables.
# *   **One-Pot Chicken and Rice:** Many recipes offer a one-pot method for a quick and easy meal with minimal cleanup. Some are creamy, while others are more like a skillet dish.
# *   **Old Fashioned Chicken and Rice:** If you're looking for Southern comfort food, this hearty, one-pot recipe often includes celery and onions.
#
# Would you like me to find a specific recipe or provide instructions for any of these?

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}  # Identifies this user's session

response = agent.invoke(
    {"messages": [HumanMessage(content="Hey am interested in making Chicken Fried Rice. can you give me full procedure?")]},
    config   # Attach to thread "1" — memory enabled
)

# Print the chef's recipe suggestions
print(response['messages'][-1].content)
# Out:
# Sure! Chicken Fried Rice is a delicious and relatively simple dish. Here's a common procedure, drawing from various recipes:
#
# **Yields:** 3-4 servings
# **Prep time:** 15-20 minutes
# **Cook time:** 15-20 minutes
#
# **Ingredients:**
#
# *   2 cups cooked rice (preferably day-old, cold rice)
# *   6-8 oz boneless, skinless chicken breast or thighs, cut into bite-sized pieces
# *   1-2 large eggs
# *   1/2 cup mixed vegetables (e.g., frozen peas and carrots, diced onion, bell pepper, corn)
# *   2-3 cloves garlic, minced
# *   1-inch piece of ginger, grated or minced (optional)
# *   2-3 tablespoons soy sauce (or to taste)
# *   1 tablespoon oyster sauce (optional, for deeper flavor)
# *   1 teaspoon sesame oil
# *   2-3 tablespoons cooking oil (like vegetable, canola, or peanut oil)
# *   Salt and pepper to taste
# *   Green onions, chopped, for garnish (optional)
#
# **Marinade for Chicken (Optional but Recommended):**
#
# *   1 teaspoon soy sauce
# *   1/2 teaspoon cornstarch
# *   1/2 teaspoon sesame oil
#
# **Instructions:**
#
# 1.  **Marinate the Chicken (Optional):** In a small bowl, combine the chicken pieces with the marinade ingredients. Toss to coat evenly and let it sit for at least 10 minutes while you prepare the other ingredients.
# 2.  **Prepare Rice:** If you don't have day-old rice, cook some white rice (long-grain or jasmine rice works well) and let it cool completely. Spreading it on a baking sheet can help it cool faster and dry out slightly. Cold, slightly dry rice is key to preventing mushy fried rice.
# 3.  **Scramble Eggs:** Heat 1 tablespoon of cooking oil in a large skillet or wok over medium-high heat. Lightly beat the eggs with a pinch of salt and pepper. Pour the eggs into the hot skillet and cook, stirring gently, until they are just set but still soft. Remove the scrambled eggs from the skillet and set aside.
# 4.  **Cook Chicken:** Add another tablespoon of cooking oil to the same skillet over medium-high heat. Add the marinated chicken (if using) or plain chicken pieces. Stir-fry until the chicken is cooked through and lightly browned. Remove the chicken from the skillet and set aside with the eggs.
# 5.  **Sauté Aromatics and Vegetables:** Add the remaining cooking oil to the skillet. Add the minced garlic and ginger (if using) and stir-fry for about 30 seconds until fragrant. Be careful not to burn the garlic. Add the diced onion and other firmer vegetables (like bell pepper) and stir-fry for 2-3 minutes until they start to soften. Add the frozen peas and carrots (or other quick-cooking vegetables) and stir-fry for another 1-2 minutes.
# 6.  **Add Rice:** Push the vegetables to one side of the skillet. Add the cold cooked rice to the empty side. Break up any clumps of rice with your spatula. Let the rice sit for a minute or two to heat through, then stir everything together.
# 7.  **Combine and Season:** Add the cooked chicken and scrambled eggs back into the skillet with the rice and vegetables. Drizzle with soy sauce, oyster sauce (if using), and sesame oil. Stir everything well to combine and ensure the sauce is evenly distributed. Continue to stir-fry for another 2-3 minutes, allowing the flavors to meld and the rice to get slightly crispy.
# 8.  **Taste and Adjust:** Taste the fried rice and add more soy sauce, salt, or pepper as needed.
# 9.  **Serve:** Garnish with chopped green onions, if desired. Serve hot.
#
# Enjoy your homemade Chicken Fried Rice!

# %%
# ============================================================
# CELL 6: Inspect the Full Message Trace
# ============================================================
# Printing the full response dict shows everything:
#
#   response['messages'][0]  HumanMessage   → user's ingredient list
#   response['messages'][1]  AIMessage      → tool call (web_search)
#       .tool_calls shows the exact query the model chose
#   response['messages'][2]  ToolMessage    → raw Tavily JSON results
#   response['messages'][3]  AIMessage      → chef's recipe suggestions
#
# The Tavily results in messages[2] are real web content —
# you can inspect them to see exactly what the model read
# before composing the recipe suggestions.
#
# 💡 If the suggestions seem off, check messages[2]:
#    - Was the search query sensible?
#    - Did Tavily return relevant results?
#    - Did the model correctly extract the recipe names?

from pprint import pprint
for item in response['messages']:
    print("=============")
    pprint(item)
# Out:
# =============
# HumanMessage(content='I have some left over chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='6205bc1c-855c-4e9d-bd4f-5e0a380f387c')
# =============
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with chicken and rice"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3693-f4b3-7520-bbff-a6e1586c4dfc-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with chicken and rice'}, 'id': '10950033-b84b-4f30-9f37-5e994ed1f2ee', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 115, 'output_tokens': 19, 'total_tokens': 134, 'input_token_details': {'cache_read': 0}})
# =============
# ToolMessage(content='{"query": "recipes with chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://cooking.nytimes.com/recipes/9118-easy-chicken-and-rice", "title": "Easy Chicken and Rice Recipe", "content": "# Easy Chicken and Rice. You can make a big deal out of chicken with rice -- at its zenith, it becomes paella -- but it is a dish that takes well to short cuts. For fast weeknight meals, I strip chicken and rice to its essentials: oil, onion, chicken and rice. To reduce greasiness, I remove the skin from the chicken before cooking it. (In a moist dish like this one, the skin is not especially appetizing anyway.) You can easily vary this dish by using any stock instead of water; by substituting another grain, like pearled barley, for the rice; by sautéing or roasting the chicken separately and combining it with the rice at the last minute; by adding sausage or shellfish, like shrimp, along with the chicken, or, most excitingly, by adding strips of red pepper, pitted olives, capers, chopped tomatoes or shelled peas to the initial onion mix. Log in or sign up to print this recipe.", "score": 0.90869105, "raw_content": null}, {"url": "https://www.acouplecooks.com/chicken-and-rice-recipe", "title": "Easy Chicken and Rice – A Couple Cooks", "content": "This one pot **chicken and rice recipe** is an easy dinner with tender chicken thighs and fluffy rice, topped with a fresh lemon parsley gremolata. If you’re looking for recipes that bring maximum flavor with minimal effort (like I am), this easy dinner idea checks every box. Yes, my one pot chicken and rice makes your kitchen smell incredible and leaves you with exactly one pan and one cutting board to wash! I have made this meal often for friends and family, and it’s a hit every time: even with picky eaters! ## Key ingredients in this chicken and rice recipe. * **Parsley and lemon:** If you’re making the gremolata (and I hope you are), you’ll need the fresh herb and fresh lemon. * **This recipe is for boneless, skinless chicken thighs.**This type cooks quicker and is easier to eat than bone-in. This chicken and rice recipe is tasty as is, but it’s even better topped with a fresh garnish.", "score": 0.8747745, "raw_content": null}, {"url": "https://www.lanascooking.com/chicken-and-rice", "title": "Old Fashioned Chicken and Rice - Lana\'s Cooking", "content": "A skillet and plate filled with old fashioned chicken and rice, served with a side of broccoli. A plate of creamy chicken and rice sits in front of a pot, with text Old Fashioned Chicken and Rice. A plate of creamy chicken and rice sits in front of a skillet, labeled “Old Fashioned Chicken & Rice.”. A skillet and plate of old fashioned chicken and rice, with utensils and garnishes on a rustic wooden table. This **Old Fashioned Chicken and Rice** recipe is one of those simple, hearty Southern comfort food dinners that’s stood the test of time. In this easy recipe, chicken, rice, celery, and onions are combined and steamed to perfection all in one pot. It’s a great meal to make on a weeknight or when you need something that really sticks to your ribs! This classic Chicken and Rice is one of those recipes.", "score": 0.8745175, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=pQYit0bzPlU", "title": "Quick and Easy One Pot Chicken and Rice | How to Make Chicken and Rice #cooking", "content": "Quick and Easy One Pot Chicken and Rice | How to Make Chicken and Rice #cooking\\nApril in the kitchen\\n49900 subscribers\\n107 likes\\n4374 views\\n26 Apr 2026\\nStop Making Dry Chicken & Rice! Easy One-Pot Chicken & Rice Are you looking for the perfect chicken recipe that goes with rice? Today I’m sharing my go-to easy one-pot chicken and rice skillet. This recipe is the ultimate creamy, smothered chicken dinner that delivers deep, soulful flavor in just 30 minutes.\\nIf you need a reliable budget-friendly meal that keeps your chicken juicy and your rice perfectly tender ...
# =============
# AIMessage(content="You have chicken and rice! Here are a few ideas for what you can make:\n\n*   **Easy Chicken and Rice:** This is a simple, classic dish that can be customized with different broths or added ingredients like sausage or vegetables.\n*   **One-Pot Chicken and Rice:** Many recipes offer a one-pot method for a quick and easy meal with minimal cleanup. Some are creamy, while others are more like a skillet dish.\n*   **Old Fashioned Chicken and Rice:** If you're looking for Southern comfort food, this hearty, one-pot recipe often includes celery and onions.\n\nWould you like me to find a specific recipe or provide instructions for any of these?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3694-2cd6-7653-b04e-51b70bad75fd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1972, 'output_tokens': 143, 'total_tokens': 2115, 'input_token_details': {'cache_read': 0}})
# =============
# HumanMessage(content='Hey am interested in making Chicken Fried Rice. can you give me full procedure?', additional_kwargs={}, response_metadata={}, id='094afa68-02a1-4dc1-960c-a044e12059ae')
# =============
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "chicken fried rice recipe instructions"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3695-3abb-7441-aecc-98e65aaf0d63-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'chicken fried rice recipe instructions'}, 'id': 'f039708c-5286-4e4d-96d3-9b86be8ec4fe', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2133, 'output_tokens': 19, 'total_tokens': 2152, 'input_token_details': {'cache_read': 1732}})
# =============
# ToolMessage(content='{"query": "chicken fried rice recipe instructions", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.delish.com/cooking/recipe-ideas/a25635966/chicken-fried-rice-recipe", "title": "Best Chicken Fried Rice Recipe", "content": "# Chicken Fried Rice. When I\'m making rice, I\'ll purposefully make too much just so I can have leftovers to make this chicken fried rice. While I love classic fried rice and all its variations, this chicken fried rice is the one I go back to again and again...and again. This easy recipe perfects every step of the process, making it easier than ever to make fried rice at home. ## **How To Make Chicken Fried Rice**. * **Veggies:** Onion, carrots, and frozen peas are my favorite choices for fried rice, but add whatever you love in fried rice. * **Garlic & Ginger:** I like my fried rice super garlicky, and you can take it back if you want, but honestly, I don’t suggest it—the more garlic, the better. Remove the chicken from the skillet, add a neutral oil, then your carrots and onions. Add in the rice and peas, and give everything a stir to combine.", "score": 0.8638634, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=mUr-7wjhHuU", "title": "Chicken Fried Rice", "content": "Chicken Fried Rice\\nCook! Stacey Cook\\n614000 subscribers\\n31689 likes\\n1582751 views\\n25 Aug 2023\\n—Ingredients(3-4servings)—\\n\\n2 cloves of garlic\\n2 stalks of green onion\\n1.76 oz/50 g       carrot\\n2 cup     cooked rice\\n1/3 cup  peas\\n2            large egg\\n6.7 oz/ 190 g      chicken\\n\\n-Chicken marinade\\n2 tsp      soy sauce\\n1 tsp      oyster sauce\\n1 tsp      wine\\n1/2 tsp   sugar\\n1/4 tsp   baking soda\\n2 tsp      corn starch\\n1/8 tsp   white pepper powder\\n2 tsp      oil\\n\\n4 tbsp   oil for cooking\\n1/4 tsp    salt\\n3 tsp     dark soy sauce\\n\\n—-Timestamps—\\n00:00 - Intro \\n00:25 - Garlic prep\\n00:34 - Green onion prep\\n00:42 - Carrot prep\\n00:57 - Chicken Prep\\n01:38 - Peas, eggs prep\\n01:43 - Rice prep\\n02:10 - How to cook chicken fried rice, Stir fry eggs\\n02:33 - Stir fry chicken\\n02:46 - Add in garlic,carrots and peas \\n03:10 - Rice stir fry\\n04:16 - Final Step\\n555 comments\\n", "score": 0.81347597, "raw_content": null}, {"url": "https://mahatmarice.com/recipes/chicken-fried-rice", "title": "Easy Chicken Fried Rice Recipe | Mahatma® Rice", "content": "Mahatma® Rice»Recipes»Chicken Fried Rice. # Chicken Fried Rice. * 1 1/2 cups Mahatma® Jasmine Rice. * For best results, use long grain and aromatic Mahatma® **Jasmine Rice** to make this **Chicken Fried Rice** for the perfect quick, simple and flavorful meal that everyone will enjoy. Stir fry the chicken, veggies and sesame oil-infused rice with soy sauce and scrambled eggs for a **restaurant-quality meal at home**. Also, to make the ideal fried rice dish, we suggest using long grain rice like Mahatma® **Jasmine Rice**, or a blend of **Long Grain and Jasmine Rice**, which is perfectly crafted for amazing fried rice dishes and other stir-fries. Our **fried rice recipe page** has many fried rice recipes that might inspire you, try out a **Bacon Fried Rice** for something a bit more crunchy, or the tangy **Ginger Pork Fried Rice.** You might even prefer to start with a flavorful base like **Coconut Jasmine Rice**.", "score": 0.8029425, "raw_content": null}, {"url": "https://thedefineddish.com/simple-chicken-fried-rice", "title": "Easy Chicken Fried Rice - The Defined Dish", "content": "Home › Recipes › Dinner › Easy Chicken Fried Rice. This **Easy Chicken Fried Rice** is on the menu often at my house, and it’s always a crowd-pleaser. Listen, I know an easy chicken fried rice recipe is not exactly groundbreaking, but it’s such a staple in my house that I felt like I had to share it. The key to making takeout-style fried rice is to using day-old white rice. That’s because rice retains a lot of moisture and fresh rice will result in a soggy fried rice. Add some ...
# =============
# AIMessage(content="Sure! Chicken Fried Rice is a delicious and relatively simple dish. Here's a common procedure, drawing from various recipes:\n\n**Yields:** 3-4 servings\n**Prep time:** 15-20 minutes\n**Cook time:** 15-20 minutes\n\n**Ingredients:**\n\n*   2 cups cooked rice (preferably day-old, cold rice)\n*   6-8 oz boneless, skinless chicken breast or thighs, cut into bite-sized pieces\n*   1-2 large eggs\n*   1/2 cup mixed vegetables (e.g., frozen peas and carrots, diced onion, bell pepper, corn)\n*   2-3 cloves garlic, minced\n*   1-inch piece of ginger, grated or minced (optional)\n*   2-3 tablespoons soy sauce (or to taste)\n*   1 tablespoon oyster sauce (optional, for deeper flavor)\n*   1 teaspoon sesame oil\n*   2-3 tablespoons cooking oil (like vegetable, canola, or peanut oil)\n*   Salt and pepper to taste\n*   Green onions, chopped, for garnish (optional)\n\n**Marinade for Chicken (Optional but Recommended):**\n\n*   1 teaspoon soy sauce\n*   1/2 teaspoon cornstarch\n*   1/2 teaspoon sesame oil\n\n**Instructions:**\n\n1.  **Marinate the Chicken (Optional):** In a small bowl, combine the chicken pieces with the marinade ingredients. Toss to coat evenly and let it sit for at least 10 minutes while you prepare the other ingredients.\n2.  **Prepare Rice:** If you don't have day-old rice, cook some white rice (long-grain or jasmine rice works well) and let it cool completely. Spreading it on a baking sheet can help it cool faster and dry out slightly. Cold, slightly dry rice is key to preventing mushy fried rice.\n3.  **Scramble Eggs:** Heat 1 tablespoon of cooking oil in a large skillet or wok over medium-high heat. Lightly beat the eggs with a pinch of salt and pepper. Pour the eggs into the hot skillet and cook, stirring gently, until they are just set but still soft. Remove the scrambled eggs from the skillet and set aside.\n4.  **Cook Chicken:** Add another tablespoon of cooking oil to the same skillet over medium-high heat. Add the marinated chicken (if using) or plain chicken pieces. Stir-fry until the chicken is cooked through and lightly browned. Remove the chicken from the skillet and set aside with the eggs.\n5.  **Sauté Aromatics and Vegetables:** Add the remaining cooking oil to the skillet. Add the minced garlic and ginger (if using) and stir-fry for about 30 seconds until fragrant. Be careful not to burn the garlic. Add the diced onion and other firmer vegetables (like bell pepper) and stir-fry for 2-3 minutes until they start to soften. Add the frozen peas and carrots (or other quick-cooking vegetables) and stir-fry for another 1-2 minutes.\n6.  **Add Rice:** Push the vegetables to one side of the skillet. Add the cold cooked rice to the empty side. Break up any clumps of rice with your spatula. Let the rice sit for a minute or two to heat through, then stir everything together.\n7.  **Combine and Season:** Add the cooked chicken and scrambled eggs back into the skillet with the rice and vegetables. Drizzle with soy sauce, oyster sauce (if using), and sesame oil. Stir everything well to combine and ensure the sauce is evenly distributed. Continue to stir-fry for another 2-3 minutes, allowing the flavors to meld and the rice to get slightly crispy.\n8.  **Taste and Adjust:** Taste the fried rice and add more soy sauce, salt, or pepper as needed.\n9.  **Serve:** Garnish with chopped green onions, if desired. Serve hot.\n\nEnjoy your homemade Chicken Fried Rice!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3695-7acf-75c0-8d9d-0c3f056cdab3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3673, 'output_tokens': 834, 'total_tokens': 4507, 'input_token_details': {'cache_read': 0}})

# %%
response = agent.invoke(
    {"message": [HumanMessage(content="Tell me how to make the chicken curry?")]},
    config
)
print(response['messages'][-1].content)

# %%
from pprint import pprint
for item in response['messages']:
    print("=============")
    pprint(item)
# Out:
# =============
# HumanMessage(content='I have some left over chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='6205bc1c-855c-4e9d-bd4f-5e0a380f387c')
# =============
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "recipes with chicken and rice"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3693-f4b3-7520-bbff-a6e1586c4dfc-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes with chicken and rice'}, 'id': '10950033-b84b-4f30-9f37-5e994ed1f2ee', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 115, 'output_tokens': 19, 'total_tokens': 134, 'input_token_details': {'cache_read': 0}})
# =============
# ToolMessage(content='{"query": "recipes with chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://cooking.nytimes.com/recipes/9118-easy-chicken-and-rice", "title": "Easy Chicken and Rice Recipe", "content": "# Easy Chicken and Rice. You can make a big deal out of chicken with rice -- at its zenith, it becomes paella -- but it is a dish that takes well to short cuts. For fast weeknight meals, I strip chicken and rice to its essentials: oil, onion, chicken and rice. To reduce greasiness, I remove the skin from the chicken before cooking it. (In a moist dish like this one, the skin is not especially appetizing anyway.) You can easily vary this dish by using any stock instead of water; by substituting another grain, like pearled barley, for the rice; by sautéing or roasting the chicken separately and combining it with the rice at the last minute; by adding sausage or shellfish, like shrimp, along with the chicken, or, most excitingly, by adding strips of red pepper, pitted olives, capers, chopped tomatoes or shelled peas to the initial onion mix. Log in or sign up to print this recipe.", "score": 0.90869105, "raw_content": null}, {"url": "https://www.acouplecooks.com/chicken-and-rice-recipe", "title": "Easy Chicken and Rice – A Couple Cooks", "content": "This one pot **chicken and rice recipe** is an easy dinner with tender chicken thighs and fluffy rice, topped with a fresh lemon parsley gremolata. If you’re looking for recipes that bring maximum flavor with minimal effort (like I am), this easy dinner idea checks every box. Yes, my one pot chicken and rice makes your kitchen smell incredible and leaves you with exactly one pan and one cutting board to wash! I have made this meal often for friends and family, and it’s a hit every time: even with picky eaters! ## Key ingredients in this chicken and rice recipe. * **Parsley and lemon:** If you’re making the gremolata (and I hope you are), you’ll need the fresh herb and fresh lemon. * **This recipe is for boneless, skinless chicken thighs.**This type cooks quicker and is easier to eat than bone-in. This chicken and rice recipe is tasty as is, but it’s even better topped with a fresh garnish.", "score": 0.8747745, "raw_content": null}, {"url": "https://www.lanascooking.com/chicken-and-rice", "title": "Old Fashioned Chicken and Rice - Lana\'s Cooking", "content": "A skillet and plate filled with old fashioned chicken and rice, served with a side of broccoli. A plate of creamy chicken and rice sits in front of a pot, with text Old Fashioned Chicken and Rice. A plate of creamy chicken and rice sits in front of a skillet, labeled “Old Fashioned Chicken & Rice.”. A skillet and plate of old fashioned chicken and rice, with utensils and garnishes on a rustic wooden table. This **Old Fashioned Chicken and Rice** recipe is one of those simple, hearty Southern comfort food dinners that’s stood the test of time. In this easy recipe, chicken, rice, celery, and onions are combined and steamed to perfection all in one pot. It’s a great meal to make on a weeknight or when you need something that really sticks to your ribs! This classic Chicken and Rice is one of those recipes.", "score": 0.8745175, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=pQYit0bzPlU", "title": "Quick and Easy One Pot Chicken and Rice | How to Make Chicken and Rice #cooking", "content": "Quick and Easy One Pot Chicken and Rice | How to Make Chicken and Rice #cooking\\nApril in the kitchen\\n49900 subscribers\\n107 likes\\n4374 views\\n26 Apr 2026\\nStop Making Dry Chicken & Rice! Easy One-Pot Chicken & Rice Are you looking for the perfect chicken recipe that goes with rice? Today I’m sharing my go-to easy one-pot chicken and rice skillet. This recipe is the ultimate creamy, smothered chicken dinner that delivers deep, soulful flavor in just 30 minutes.\\nIf you need a reliable budget-friendly meal that keeps your chicken juicy and your rice perfectly tender ...
# =============
# AIMessage(content="You have chicken and rice! Here are a few ideas for what you can make:\n\n*   **Easy Chicken and Rice:** This is a simple, classic dish that can be customized with different broths or added ingredients like sausage or vegetables.\n*   **One-Pot Chicken and Rice:** Many recipes offer a one-pot method for a quick and easy meal with minimal cleanup. Some are creamy, while others are more like a skillet dish.\n*   **Old Fashioned Chicken and Rice:** If you're looking for Southern comfort food, this hearty, one-pot recipe often includes celery and onions.\n\nWould you like me to find a specific recipe or provide instructions for any of these?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3694-2cd6-7653-b04e-51b70bad75fd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1972, 'output_tokens': 143, 'total_tokens': 2115, 'input_token_details': {'cache_read': 0}})
# =============
# HumanMessage(content='Hey am interested in making Chicken Fried Rice. can you give me full procedure?', additional_kwargs={}, response_metadata={}, id='094afa68-02a1-4dc1-960c-a044e12059ae')
# =============
# AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "chicken fried rice recipe instructions"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3695-3abb-7441-aecc-98e65aaf0d63-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'chicken fried rice recipe instructions'}, 'id': 'f039708c-5286-4e4d-96d3-9b86be8ec4fe', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2133, 'output_tokens': 19, 'total_tokens': 2152, 'input_token_details': {'cache_read': 1732}})
# =============
# ToolMessage(content='{"query": "chicken fried rice recipe instructions", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.delish.com/cooking/recipe-ideas/a25635966/chicken-fried-rice-recipe", "title": "Best Chicken Fried Rice Recipe", "content": "# Chicken Fried Rice. When I\'m making rice, I\'ll purposefully make too much just so I can have leftovers to make this chicken fried rice. While I love classic fried rice and all its variations, this chicken fried rice is the one I go back to again and again...and again. This easy recipe perfects every step of the process, making it easier than ever to make fried rice at home. ## **How To Make Chicken Fried Rice**. * **Veggies:** Onion, carrots, and frozen peas are my favorite choices for fried rice, but add whatever you love in fried rice. * **Garlic & Ginger:** I like my fried rice super garlicky, and you can take it back if you want, but honestly, I don’t suggest it—the more garlic, the better. Remove the chicken from the skillet, add a neutral oil, then your carrots and onions. Add in the rice and peas, and give everything a stir to combine.", "score": 0.8638634, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=mUr-7wjhHuU", "title": "Chicken Fried Rice", "content": "Chicken Fried Rice\\nCook! Stacey Cook\\n614000 subscribers\\n31689 likes\\n1582751 views\\n25 Aug 2023\\n—Ingredients(3-4servings)—\\n\\n2 cloves of garlic\\n2 stalks of green onion\\n1.76 oz/50 g       carrot\\n2 cup     cooked rice\\n1/3 cup  peas\\n2            large egg\\n6.7 oz/ 190 g      chicken\\n\\n-Chicken marinade\\n2 tsp      soy sauce\\n1 tsp      oyster sauce\\n1 tsp      wine\\n1/2 tsp   sugar\\n1/4 tsp   baking soda\\n2 tsp      corn starch\\n1/8 tsp   white pepper powder\\n2 tsp      oil\\n\\n4 tbsp   oil for cooking\\n1/4 tsp    salt\\n3 tsp     dark soy sauce\\n\\n—-Timestamps—\\n00:00 - Intro \\n00:25 - Garlic prep\\n00:34 - Green onion prep\\n00:42 - Carrot prep\\n00:57 - Chicken Prep\\n01:38 - Peas, eggs prep\\n01:43 - Rice prep\\n02:10 - How to cook chicken fried rice, Stir fry eggs\\n02:33 - Stir fry chicken\\n02:46 - Add in garlic,carrots and peas \\n03:10 - Rice stir fry\\n04:16 - Final Step\\n555 comments\\n", "score": 0.81347597, "raw_content": null}, {"url": "https://mahatmarice.com/recipes/chicken-fried-rice", "title": "Easy Chicken Fried Rice Recipe | Mahatma® Rice", "content": "Mahatma® Rice»Recipes»Chicken Fried Rice. # Chicken Fried Rice. * 1 1/2 cups Mahatma® Jasmine Rice. * For best results, use long grain and aromatic Mahatma® **Jasmine Rice** to make this **Chicken Fried Rice** for the perfect quick, simple and flavorful meal that everyone will enjoy. Stir fry the chicken, veggies and sesame oil-infused rice with soy sauce and scrambled eggs for a **restaurant-quality meal at home**. Also, to make the ideal fried rice dish, we suggest using long grain rice like Mahatma® **Jasmine Rice**, or a blend of **Long Grain and Jasmine Rice**, which is perfectly crafted for amazing fried rice dishes and other stir-fries. Our **fried rice recipe page** has many fried rice recipes that might inspire you, try out a **Bacon Fried Rice** for something a bit more crunchy, or the tangy **Ginger Pork Fried Rice.** You might even prefer to start with a flavorful base like **Coconut Jasmine Rice**.", "score": 0.8029425, "raw_content": null}, {"url": "https://thedefineddish.com/simple-chicken-fried-rice", "title": "Easy Chicken Fried Rice - The Defined Dish", "content": "Home › Recipes › Dinner › Easy Chicken Fried Rice. This **Easy Chicken Fried Rice** is on the menu often at my house, and it’s always a crowd-pleaser. Listen, I know an easy chicken fried rice recipe is not exactly groundbreaking, but it’s such a staple in my house that I felt like I had to share it. The key to making takeout-style fried rice is to using day-old white rice. That’s because rice retains a lot of moisture and fresh rice will result in a soggy fried rice. Add some ...
# =============
# AIMessage(content="Sure! Chicken Fried Rice is a delicious and relatively simple dish. Here's a common procedure, drawing from various recipes:\n\n**Yields:** 3-4 servings\n**Prep time:** 15-20 minutes\n**Cook time:** 15-20 minutes\n\n**Ingredients:**\n\n*   2 cups cooked rice (preferably day-old, cold rice)\n*   6-8 oz boneless, skinless chicken breast or thighs, cut into bite-sized pieces\n*   1-2 large eggs\n*   1/2 cup mixed vegetables (e.g., frozen peas and carrots, diced onion, bell pepper, corn)\n*   2-3 cloves garlic, minced\n*   1-inch piece of ginger, grated or minced (optional)\n*   2-3 tablespoons soy sauce (or to taste)\n*   1 tablespoon oyster sauce (optional, for deeper flavor)\n*   1 teaspoon sesame oil\n*   2-3 tablespoons cooking oil (like vegetable, canola, or peanut oil)\n*   Salt and pepper to taste\n*   Green onions, chopped, for garnish (optional)\n\n**Marinade for Chicken (Optional but Recommended):**\n\n*   1 teaspoon soy sauce\n*   1/2 teaspoon cornstarch\n*   1/2 teaspoon sesame oil\n\n**Instructions:**\n\n1.  **Marinate the Chicken (Optional):** In a small bowl, combine the chicken pieces with the marinade ingredients. Toss to coat evenly and let it sit for at least 10 minutes while you prepare the other ingredients.\n2.  **Prepare Rice:** If you don't have day-old rice, cook some white rice (long-grain or jasmine rice works well) and let it cool completely. Spreading it on a baking sheet can help it cool faster and dry out slightly. Cold, slightly dry rice is key to preventing mushy fried rice.\n3.  **Scramble Eggs:** Heat 1 tablespoon of cooking oil in a large skillet or wok over medium-high heat. Lightly beat the eggs with a pinch of salt and pepper. Pour the eggs into the hot skillet and cook, stirring gently, until they are just set but still soft. Remove the scrambled eggs from the skillet and set aside.\n4.  **Cook Chicken:** Add another tablespoon of cooking oil to the same skillet over medium-high heat. Add the marinated chicken (if using) or plain chicken pieces. Stir-fry until the chicken is cooked through and lightly browned. Remove the chicken from the skillet and set aside with the eggs.\n5.  **Sauté Aromatics and Vegetables:** Add the remaining cooking oil to the skillet. Add the minced garlic and ginger (if using) and stir-fry for about 30 seconds until fragrant. Be careful not to burn the garlic. Add the diced onion and other firmer vegetables (like bell pepper) and stir-fry for 2-3 minutes until they start to soften. Add the frozen peas and carrots (or other quick-cooking vegetables) and stir-fry for another 1-2 minutes.\n6.  **Add Rice:** Push the vegetables to one side of the skillet. Add the cold cooked rice to the empty side. Break up any clumps of rice with your spatula. Let the rice sit for a minute or two to heat through, then stir everything together.\n7.  **Combine and Season:** Add the cooked chicken and scrambled eggs back into the skillet with the rice and vegetables. Drizzle with soy sauce, oyster sauce (if using), and sesame oil. Stir everything well to combine and ensure the sauce is evenly distributed. Continue to stir-fry for another 2-3 minutes, allowing the flavors to meld and the rice to get slightly crispy.\n8.  **Taste and Adjust:** Taste the fried rice and add more soy sauce, salt, or pepper as needed.\n9.  **Serve:** Garnish with chopped green onions, if desired. Serve hot.\n\nEnjoy your homemade Chicken Fried Rice!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f3695-7acf-75c0-8d9d-0c3f056cdab3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3673, 'output_tokens': 834, 'total_tokens': 4507, 'input_token_details': {'cache_read': 0}})
# =============
# AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f369b-10d5-7c33-9401-950dc9233a51-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4508, 'output_tokens': 0, 'total_tokens': 4508, 'input_token_details': {'cache_read': 3762}})
# =============
# AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f369b-b55d-7050-b061-5ca85bc4800e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4509, 'output_tokens': 0, 'total_tokens': 4509, 'input_token_details': {'cache_read': 3763}})
# =============
# AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f369c-4390-7c02-9b66-6edbb9da24f7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4510, 'output_tokens': 0, 'total_tokens': 4510, 'input_token_details': {'cache_read': 0}})
# =============
# AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f369e-6c7e-7db1-9bed-0d874d0a8a80-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4511, 'output_tokens': 0, 'total_tokens': 4511, 'input_token_details': {'cache_read': 0}})
# =============
# AIMessage(content='', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f369f-581b-7ad2-b2f9-62f554ad7cc0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 4512, 'output_tokens': 0, 'total_tokens': 4512, 'input_token_details': {'cache_read': 3766}})

# %% [markdown]
# ---
# ## Try It Yourself — Follow-Up Turns
#
# Because memory is enabled, you can now continue the conversation naturally. Try adding a new cell with:
#
# ```python
# response = agent.invoke(
#     {"messages": [HumanMessage(content="Tell me how to make the fried rice")]},
#     config   # Same thread_id — agent remembers the chicken and rice
# )
# print(response['messages'][-1].content)
# ```
#
# The agent will:
# 1. Load the full history (ingredients + first suggestions)
# 2. Know you mean the chicken fried rice it suggested earlier
# 3. Search for step-by-step instructions
# 4. Return the full recipe
#
# You never had to repeat "chicken and rice" — that's memory working.

# %% [markdown]
# ---
# ## Summary — What Makes This a Real Application
#
# | Component | Role in the app |
# |---|---|
# | `system_prompt` | Defines the chef persona and forces web search usage |
# | `web_search` tool | Ensures recipes are real and current, not hallucinated |
# | `InMemorySaver` | Lets the user say "make the first one" without repeating ingredients |
# | `thread_id` | Isolates each user's conversation (in a real app: one per user session) |
# | `[-1].content` | Always the final answer — safe regardless of how many tool calls happened |
#
# ### How to turn this into a production app
#
# 1. **Web API**: wrap the agent in a FastAPI endpoint — each request passes the `thread_id` from the user's session cookie
# 2. **Persistent memory**: swap `InMemorySaver` for `PostgresSaver` — memory survives server restarts
# 3. **Streaming**: use `agent.stream(..., stream_mode="messages")` so the user sees the recipe appear word-by-word
# 4. **Deploy**: see `langgraph.json` in this project — it configures the agent for deployment via LangGraph Cloud
#
# ### The `langgraph.json` file
#
# The `langgraph.json` file in this project tells the LangGraph deployment platform:
# - Which Python file and object to use as the agent (`1.5_personal_chef.py:agent`)
# - Where to find dependencies (the current directory)
# - Which `.env` file to use for API keys
#
# This is how you go from a notebook prototype to a hosted API in one command: `langgraph up`.
