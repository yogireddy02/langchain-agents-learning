# %% [markdown]
# # 1.5 Personal Chef — A Complete Agent Application
#
# ## What this notebook demonstrates
#
# This is the **capstone project** for Module 1. It combines every concept from the previous notebooks into one working application:
#
# | Concept | Where it's used |
# |---|---|
# | **Agent** | `create_agent()` — the orchestration backbone |
# | **System prompt** | Chef persona + task description |
# | **Tool** | `web_search` — live recipe lookup via Tavily |
# | **Memory** | `InMemorySaver` — remembers ingredients across turns |
# | **Multi-turn conversation** | `thread_id` + `config` — user can follow up |
#
# ### The application
#
# A **Personal Chef agent** that:
# 1. Takes a list of ingredients the user has at home
# 2. Searches the web for real recipes using those ingredients
# 3. Suggests options and provides full instructions on request
# 4. Remembers the conversation — no need to repeat the ingredient list
#
# This is a pattern you can reuse for any domain: swap "chef" for "travel agent", "fitness coach", "financial advisor", etc.
#
# ---
#
# ### Architecture overview
#
# ```
# User: "I have chicken and rice"
#          │
#          ▼
#     ┌──────────────────────────────────────┐
#     │            Agent Loop                │
#     │  ┌─────────────────────────────┐     │
#     │  │  System Prompt (Chef persona)│     │
#     │  └─────────────────────────────┘     │
#     │                 │                    │
#     │          ┌──────▼──────┐             │
#     │          │   LLM Brain  │             │
#     │          └──────┬──────┘             │
#     │                 │ decides to search  │
#     │          ┌──────▼──────┐             │
#     │          │  web_search  │ → Tavily   │
#     │          │  (tool)      │ ← results  │
#     │          └──────┬──────┘             │
#     │                 │                    │
#     │          ┌──────▼──────┐             │
#     │          │  LLM Brain  │             │
#     │          │ (summarises) │             │
#     │          └──────┬──────┘             │
#     └─────────────────┼────────────────────┘
#                       │
#          ┌────────────▼──────────────┐
#          │  InMemorySaver (thread 1)  │  ← saves history
#          └───────────────────────────┘
#                       │
#          ▼
#     "Here are some recipes: 1) Chicken Fried Rice..."
# ```

# %%
# ============================================================
# CELL 1: Load Environment Variables
# ============================================================
# Requires in .env:
#   OPENAI_API_KEY=sk-...      (for the LLM)
#   TAVILY_API_KEY=tvly-...    (for web search)

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# ============================================================
# CELL 2: Define the Web Search Tool
# ============================================================
# The same Tavily-backed tool from notebook 1.2.
# We define it here so this notebook is self-contained.
#
# The chef agent will use this tool to look up REAL recipes
# from the internet — not hallucinated ones from training data.
# This is critical for a recipe app where accuracy and safety
# (correct cooking times, temperatures) matter.
#
# Query examples the model will construct autonomously:
#   "chicken rice recipe easy"   → for ingredient-based search
#   "chicken fried rice recipe step by step"  → when user asks for details

from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()  # Reads TAVILY_API_KEY from env

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web for information"""
    return tavily_client.search(query)

# %%
# ============================================================
# CELL 3: Define the System Prompt
# ============================================================
# A good system prompt for a tool-enabled agent answers:
#   WHO:   "You are a personal chef"
#   WHAT:  "The user gives you ingredients"
#   HOW:   "Search the web for recipes" (explicitly instructs tool use)
#   OUTPUT:"Return suggestions and instructions on request"
#
# Note that we explicitly say "Using the web search tool" — this
# nudges the model to always search rather than rely on potentially
# stale or hallucinated recipes from training data.
#
# The phrase "if requested" for instructions is important:
# without it the model might dump the full recipe on every turn,
# making the conversation overwhelming. With it, it first suggests
# options and waits to be asked for details.

system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
# ============================================================
# CELL 4: Build the Complete Agent
# ============================================================
# This one create_agent call wires together all the components:
#
#   model="gpt-5-nano"        → the LLM that reasons and generates text
#   tools=[web_search]        → the tool it can call (Tavily search)
#   system_prompt=system_prompt → the chef persona and task instructions
#   checkpointer=InMemorySaver() → per-thread conversation memory
#
# InMemorySaver is initialised fresh here — it starts empty.
# As we make invoke() calls with a thread_id, it fills up with
# the conversation history for that thread.

from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()  # Enables multi-turn memory
)

# %%
# ============================================================
# CELL 5: Turn 1 — Tell the Chef What Ingredients You Have
# ============================================================
# config binds this call to thread_id="1".
# We set config once and reuse it for all turns in this session.
#
# What the agent will do:
#   1. Read the system prompt (chef persona)
#   2. Read the user message (chicken + rice)
#   3. Decide to call web_search (the prompt says to search)
#   4. Formulate a query like "chicken rice leftover recipes"
#   5. Read Tavily results
#   6. Summarise 3-5 recipe options in natural language
#
# The InMemorySaver saves the full message history under thread_id="1"
# after this call — so the next call will remember the ingredients.

from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}  # Identifies this user's session

response = agent.invoke(
    {"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]},
    config   # Attach to thread "1" — memory enabled
)

# Print the chef's recipe suggestions
print(response['messages'][-1].content)
# Out:
# Nice—we can turn leftover chicken and rice into several quick, tasty meals. Here are a few solid options that fit what you’ve got, with a sense of what extra ingredients they typically need and how long they take.
#
# 1) Chicken Fried Rice (classic)
# - What it is: A fast skillet/stir-fry using day- or night-before rice, chopped chicken, and scrambled egg, with soy sauce and a little sesame oil.
# - What you’ll likely need beyond leftovers: soy sauce, eggs, onion or scallions, garlic, peas/carrots (frozen ok), sesame oil.
# - Time: About 15–25 minutes.
# - Why it’s good for leftovers: Uses both chicken and rice, comes together in minutes.
# - Quick note: Many versions exist; you can customize with any veggies you have.
# - Ideas to flavor: a splash of oyster sauce or a pinch of white pepper.
# - Example inspirations: chicken fried rice recipes widely shared by Delish, The Recipe Critic, Cooking Classy, Pioneer Woman, Averie Cooks, etc.
#
# 2) One-Pan Cheesy Chicken and Rice C casserole (creamy, cozy)
# - What it is: A one-dish bake that combines chicken, rice, and a creamy sauce (often with cheese) into a comforting casserole.
# - What you’ll need beyond leftovers: cream of mushroom or chicken soup (or a simple homemade cream sauce), milk or stock, shredded cheese; optional veggies.
# - Time: About 45–60 minutes in the oven.
# - Why it’s good for leftovers: Simple to “re-square” leftovers into a hearty bake.
# - Example inspirations: Crazy for Crust, Tastes Better From Scratch, The Country Cook, Spend with Pennies, etc.
#
# 3) Simple Chicken and Rice Casserole (easy, pantry-friendly)
# - What it is: A straightforward casserole using leftover chicken and rice, often with Cream of Chicken/Mushroom soups and a bit of cheese or breadcrumbs on top.
# - What you’ll need beyond leftovers: canned soups or a creamy base, some milk or stock, cheese or breadcrumbs for topping.
# - Time: About 60 minutes total (prep + bake).
# - Why it’s good for leftovers: Very forgiving and adaptable to what you have on hand.
# - Inspirations: The Country Cook, Tastes Better From Scratch, Spend with Pennies, etc.
#
# 4) Leftover Chicken and Egg Fried Rice (slightly different take)
# - What it is: A fried-rice style dish focusing on egg as a binding, with optional veggies and a bit of soy.
# - What you’ll need beyond leftovers: eggs, soy sauce, onion/garlic, possibly peas/carrot mix.
# - Time: 15–20 minutes.
# - Why it’s good for leftovers: Very quick and uses up both proteins and rice efficiently.
# - Inspiration: Easy Peasy Foodie (leftover chicken fried rice).
#
# 5) Quick “Better-Than-Takeout” Chicken Fried Rice (tasty, crowd-pleaser)
# - What it is: A more polished fried rice with a robust flavor profile (garlic, ginger, sesame oil, soy, veggies, eggs).
# - What you’ll need beyond leftovers: garlic, ginger (fresh if you have it), soy sauce, sesame oil, vegetables of choice.
# - Time: Around 20 minutes.
# - Why it’s good for leftovers: Flavors come together fast and it’s hard to beat for weeknights.
#
# Would you like me to pull full, step-by-step instructions for any of these options? If you tell me which one you’re leaning toward (or tell me what extra ingredients you have on hand, like soy sauce, eggs, veggies, cream soups, cheese, etc.), I can tailor a precise recipe with quantities and steps. Also, tell me any dietary preferences or restrictions (low-sodium, gluten-free, dairy-free, etc.) and I’ll adjust.

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}  # Identifies this user's session

response = agent.invoke(
    {"messages": [HumanMessage(content="Hey am interested in making Chicken Fried Rice. can you give me full procedure?")]},
    config   # Attach to thread "1" — memory enabled
)

# Print the chef's recipe suggestions
print(response['messages'][-1].content)
# Out:
# Great choice. Here’s a full, easy-to-follow Chicken Fried Rice recipe designed for using leftover chicken and rice.
#
# Servings: 2–3
# Prep time: 5 minutes
# Cook time: 15–20 minutes
#
# Ingredients
# - 2 cups leftover cooked rice (day-old rice works best; break up any clumps)
# - 1 cup cooked chicken, diced or shredded
# - 2 medium eggs, lightly beaten
# - 1 small onion, finely chopped
# - 2 cloves garlic, minced
# - 1 cup mixed vegetables (frozen peas and carrots are perfect; you can use corn, bell peppers, etc.)
# - 2–3 tablespoons soy sauce (to taste)
# - 1 tablespoon oyster sauce (optional, for depth)
# - 1 teaspoon sesame oil (optional but nice)
# - 2 tablespoons neutral oil (vegetable or canola) for frying
# - Optional garnish: sliced green onions, sesame seeds, chili flakes
#
# Equipment
# - Large skillet or wok
# - Spatula or wooden spoon
# - Grater or knife for mincing garlic
#
# Procedure
# 1) Prep everything. Break up the rice with your hands or a fork so there are no big clumps. Chop the chicken if not already small pieces. Have your onion, garlic, and veggies ready.
#
# 2) Heat the pan. Place a large skillet or wok over high heat. Add 1 tablespoon of neutral oil and swirl to coat.
#
# 3) Scramble the eggs. Push the oil to the edges, pour in the beaten eggs in the center, and scramble until just set. Remove the eggs from the pan and set aside.
#
# 4) Sauté aromatics. Add the remaining 1 tablespoon oil to the hot pan. Add the onion and cook 2–3 minutes until translucent. Add the garlic and cook about 30 seconds more, until fragrant.
#
# 5) Add chicken. Add the chopped chicken to the pan and cook 1–2 minutes until it’s heated through and slightly hot.
#
# 6) Add rice. Add the rice to the pan. Stir-fry, spreading it out in the pan so it can fry a bit. Let it sit for about 20–30 seconds, then stir to break up any remaining lumps. Repeat a few times.
#
# 7) Add vegetables. Stir in the vegetables and cook 2–3 minutes until they’re heated through and tender-crisp.
#
# 8) Season. Return the scrambled eggs to the pan. Add soy sauce and oyster sauce (if using), and drizzle with sesame oil. Toss everything to combine and heat through. Taste and adjust soy sauce if needed.
#
# 9) Finish and serve. Remove from heat, sprinkle with green onions if you have them, and serve hot.
#
# Tips and variations
# - For more color and flavor, add diced bell peppers or grated ginger with the onion.
# - If you like it spicy, whisk in a little chili paste or sriracha with the soy sauce.
# - If you don’t have oyster sauce, you can omit it or replace with a tiny splash of fish sauce or a pinch of sugar for balance.
# - Make it healthier: use brown rice, or add more veggies like broccoli, snap peas, or corn.
# - Storing: refrigerate leftovers promptly and use within 3–4 days. Reheat in a hot skillet or microwave until steaming hot.
#
# Would you like me to tailor this to what you actually have in your fridge (specific veggies or sauces like ginger, sesame seeds, scallions, or chili sauce)? I can adjust measurements and add steps if you have any dietary preferences.

# %%
# ============================================================
# CELL 6: Inspect the Full Message Trace
# ============================================================
# Printing the full response dict shows everything:
#
#   response['messages'][0]  HumanMessage   → user's ingredient list
#   response['messages'][1]  AIMessage      → tool call (web_search)
#       .tool_calls shows the exact query the model chose
#   response['messages'][2]  ToolMessage    → raw Tavily JSON results
#   response['messages'][3]  AIMessage      → chef's recipe suggestions
#
# The Tavily results in messages[2] are real web content —
# you can inspect them to see exactly what the model read
# before composing the recipe suggestions.
#
# 💡 If the suggestions seem off, check messages[2]:
#    - Was the search query sensible?
#    - Did Tavily return relevant results?
#    - Did the model correctly extract the recipe names?

from pprint import pprint
for item in response['messages']:
    print("=============")
    pprint(item)
# Out:
# =============
# HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='00936251-1ded-435b-9fbb-85dc9671e7d5')
# =============
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 412, 'prompt_tokens': 199, 'total_tokens': 611, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DLJi5gNU1FFDZQ6ruSJPJla0yYdCK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d0908-2afc-7071-a4f9-eb5f41b8bedb-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'recipes using leftover chicken and rice'}, 'id': 'call_kV6mUSL8l6K5xKdFyQF3w0mP', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 199, 'output_tokens': 412, 'total_tokens': 611, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})
# =============
# ToolMessage(content='{"query": "recipes using leftover chicken and rice", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=6ioZjlmtKv8", "title": "Leftover Chicken and Rice Recipe For Dinner - YouTube", "content": "This Easy and delicious dinner is made with leftover baked chicken and leftover rice. it\'s amazing how you can create a quick and easy", "score": 0.99998844, "raw_content": null}, {"url": "https://www.easypeasyfoodie.com/leftover-chicken-egg-fried-rice/", "title": "Leftover Chicken and Egg Fried Rice - Easy Peasy Foodie", "content": "Home » All Recipes » Easy Midweek Meal Ideas » **Leftover Chicken and Egg Fried Rice**. *An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? An easy, quick and family friendly meal, Leftover Chicken and Egg Fried Rice is perfect for a busy weeknight and a great way to use up your roast chicken leftovers…No leftover chicken? And also I like my rice really crispy when I make egg fried rice which is why I tend to cook it a little longer and over a reasonably high heat – I just love those little crispy bits!! OR just notice she has UK / US toggle on the recipe.Since I’m in the US, happened to miss the toggle but was excited to use up rice, chicken & make an easy meal… I googled & I had an amazing dish in 5 minutes later.", "score": 0.9999815, "raw_content": null}, {"url": "https://www.reddit.com/r/recipes/comments/4dsvy6/what_can_i_make_with_already_cooked_chicken_and/", "title": "What can I make with already cooked chicken and rice? - Reddit", "content": "Lemon Chicken Rice Soup, I do it all the time with chicken and rice leftovers! Simmer cooked chicken, prepared rice, 4 cups chicken broth, 1/3", "score": 0.99980444, "raw_content": null}, {"url": "https://www.facebook.com/groups/843066235833642/posts/3044839922322918/", "title": "What are some meal ideas using chicken breast and leftover rice?", "content": "Got leftover rice? Try out the Chicken Rice Soup. Simply add chicken breast pieces, potatoes or mixed veggies to the leftover rice and bring to", "score": 0.99980444, "raw_content": null}, {"url": "https://quickweeknightmeals.com/chicken-fried-rice/", "title": "Chicken Fried Rice - Quick Weeknight Meals", "content": "# Chicken Fried Rice. *Simple and delicious **Chicken Fried Rice** is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner.*. I used leftover rotisserie chicken and leftover rice in this. You can\'t go wrong with chicken and rice in a sesame and soy sauce. * **Green onions** - these are going in the fried rice and on top before serving. * **Cold rice** - cold rice makes the best fried rice so use leftover rice or cook the rice the night before. ## How To Make Chicken Fried Rice. * **Add remaining ingredients.** Add rice, chicken, and soy sauce. Chicken fried rice is good for up to 3 days. You can freeze chicken fried rice for up to 3 months. ## Chicken Fried Rice. Simple and delicious Chicken Fried Rice is perfect for a weeknight! Use leftover chicken and rice to make this easy one pan dinner. 5. Add rice, chicken, and soy sauce.", "score": 0.9997731, "raw_content": null}], "response_time": 0.74, "request_id": "3c755562-70fa-4a9e-9fa9-a5d8843049f0"}', name='web_search', id='5e2d541d-9b79-42f8-a32e-91911075fd40', tool_call_id='call_kV6mUSL8l6K5xKdFyQF3w0mP')
# =============
# AIMessage(content='Nice—chicken and rice are a perfect pairing. Here are a few tasty options you can make, based on what you have and what other home cooks do with leftovers:\n\n- Leftover Chicken and Egg Fried Rice ( Easy Peasy Foodie )\n  - Quick, one-pan dish. Uses leftover chicken and rice, scrambled eggs, and a splash of soy sauce. Great with a few veggies if you have them.\n  - Link for full instructions: Easy Peasy Foodie – Leftover Chicken and Egg Fried Rice\n\n- Chicken Fried Rice ( Quick Weeknight Meals )\n  - Classic fried rice, one-pan meal. Uses leftover chicken and rice, soy sauce, sesame, and green onions. Best with cold, day-old rice for extra texture.\n  - Link for full instructions: Quick Weeknight Meals – Chicken Fried Rice\n\n- Lemon Chicken Rice Soup (idea you can adapt)\n  - Simple soothing soup you can assemble with leftover chicken and rice, plus chicken broth and lemon. A cozy option if you want something warmer and broth-based.\n  - Source note: one user suggests this approach for cooked chicken and rice leftovers; you can customize with any veggies you have.\n\nWant me to pull full step-by-step instructions for one or more of these? Tell me which option you’d like, or share what you have on hand (any veggies, spices, or dietary preferences), and I’ll tailor a recipe and give you the exact steps.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2028, 'prompt_tokens': 1089, 'total_tokens': 3117, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1728, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DLJiARxIFgbD75tZtgb68O6VJPP83', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d0908-43f8-71f1-85a3-f74621a44853-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1089, 'output_tokens': 2028, 'total_tokens': 3117, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1728}})
# =============
# HumanMessage(content='Hey am interested in making Chicken Fried Rice. can you give me full procedure?', additional_kwargs={}, response_metadata={}, id='563aed27-ddc1-465b-9f3a-8ac5937d76db')
# =============
# AIMessage(content='Great choice. Here’s a full, easy Chicken Fried Rice you can make with leftover chicken and rice. It’s flexible, so tweak quantities to what you have.\n\nIngredients (serves 2–3)\n- 2 cups cold cooked rice (day-old rice works best)\n- 1 cup cooked chicken, shredded or diced\n- 2 eggs\n- 1 small onion, diced (or 2 scallions, sliced)\n- 2 cloves garlic, minced\n- 1 teaspoon fresh ginger, grated (optional)\n- 1/2 cup frozen peas and carrots (or any quick-cook veggies you have)\n- 2–3 tablespoons soy sauce (adjust to taste)\n- 1 teaspoon oyster sauce or 1 teaspoon hoisin (optional, for depth)\n- 1 teaspoon sesame oil (plus a little extra for finishing)\n- 1–2 tablespoons neutral oil (vegetable or canola)\n- Salt and pepper to taste\n- Garnish: sliced green onions or extra sesame seeds (optional)\n- Optional heat: chili flakes or sriracha to serve\n\nSteps\n1) Prep\n- Break up the rice with a fork so there are no big clumps.\n- Beat the eggs in a small bowl.\n- Have the chicken, veggies, and sauces ready within reach.\n\n2) Scramble the eggs\n- Heat 1 tablespoon oil in a large skillet or wok over medium-high heat.\n- Pour in the eggs and scramble until just set. Remove them from the pan and set aside.\n\n3) Sauté aromatics\n- Add another tablespoon oil to the pan.\n- Add onion (and garlic and ginger, if using). Sauté 1–2 minutes until fragrant and translucent.\n\n4) Add chicken and veggies\n- Add the chicken and cook for 2–3 minutes until heated through.\n- Stir in peas and carrots (or other veggies). Cook 1–2 minutes until they’re tender but still bright.\n\n5) Fry the rice\n- Add the cold rice to the pan. Use a spatula to press and break up any remaining clumps.\n- Push everything to the side of the pan to create a well. Drizzle soy sauce (and oyster/hoisin if using) into the well.\n- Stir to coat the rice evenly with the sauce. Cook 4–5 minutes, letting the rice get a bit of color if you like.\n- Drizzle sesame oil over the rice and toss to combine.\n\n6) Finish\n- Return the scrambled eggs to the pan. Mix everything until evenly distributed and heated through.\n- Taste and adjust seasoning with salt, pepper, or more soy sauce as needed.\n\n7) Serve\n- Scoop into bowls, garnish with green onions or sesame seeds, and serve hot. If you like heat, add a drizzle of sriracha.\n\nTips\n- Use only cold, day-old rice for best texture; freshly cooked rice can be too soft and sticky.\n- Cook on fairly high heat so the rice gets a bit of crispiness instead of steaming.\n- If you’re low on soy sauce, you can mix a splash of soy with a little water and a pinch of sugar to mimic a balanced glaze.\n\nWould you like me to tailor this to what you have on hand (any other veggies, sauces, or dietary needs like gluten-free or low-sodium)? I can adjust quantities and suggest a quick grocery substitutions list.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1851, 'prompt_tokens': 1405, 'total_tokens': 3256, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1152, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DLJjuVohKxosNyYEcbyihDCHDOjJd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d0909-e92f-7fa2-a379-4daca8d9ea1f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1405, 'output_tokens': 1851, 'total_tokens': 3256, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1152}})

# %% [markdown]
# ---
# ## Try It Yourself — Follow-Up Turns
#
# Because memory is enabled, you can now continue the conversation naturally. Try adding a new cell with:
#
# ```python
# response = agent.invoke(
#     {"messages": [HumanMessage(content="Tell me how to make the fried rice")]},
#     config   # Same thread_id — agent remembers the chicken and rice
# )
# print(response['messages'][-1].content)
# ```
#
# The agent will:
# 1. Load the full history (ingredients + first suggestions)
# 2. Know you mean the chicken fried rice it suggested earlier
# 3. Search for step-by-step instructions
# 4. Return the full recipe
#
# You never had to repeat "chicken and rice" — that's memory working.

# %% [markdown]
# ---
# ## Summary — What Makes This a Real Application
#
# | Component | Role in the app |
# |---|---|
# | `system_prompt` | Defines the chef persona and forces web search usage |
# | `web_search` tool | Ensures recipes are real and current, not hallucinated |
# | `InMemorySaver` | Lets the user say "make the first one" without repeating ingredients |
# | `thread_id` | Isolates each user's conversation (in a real app: one per user session) |
# | `[-1].content` | Always the final answer — safe regardless of how many tool calls happened |
#
# ### How to turn this into a production app
#
# 1. **Web API**: wrap the agent in a FastAPI endpoint — each request passes the `thread_id` from the user's session cookie
# 2. **Persistent memory**: swap `InMemorySaver` for `PostgresSaver` — memory survives server restarts
# 3. **Streaming**: use `agent.stream(..., stream_mode="messages")` so the user sees the recipe appear word-by-word
# 4. **Deploy**: see `langgraph.json` in this project — it configures the agent for deployment via LangGraph Cloud
#
# ### The `langgraph.json` file
#
# The `langgraph.json` file in this project tells the LangGraph deployment platform:
# - Which Python file and object to use as the agent (`1.5_personal_chef.py:agent`)
# - Where to find dependencies (the current directory)
# - Which `.env` file to use for API keys
#
# This is how you go from a notebook prototype to a hosted API in one command: `langgraph up`.
